# %%
import pandas as pd
import numpy as np

# %%
namki = pd.read_csv("M1_data_pepTestCustomers.csv")

# %%
namki.head()
# Out:
#         id  age  sex  region   income  married  children  car  save_act  \
# 0  ID12101   48    0       0  17546.0        0         1    0         0
# 1  ID12102   40    1       3  30085.1        1         3    1         0
# 2  ID12103   51    0       0  16575.4        1         0    1         1
# 3  ID12104   23    0       3  20375.4        1         3    0         0
# 4  ID12105   57    0       1  50576.3        1         0    0         1
#
#    current_act  mortgage  pep
# 0            0         0    1
# 1            1         1    0
# 2            1         0    0
# 3            1         0    0
# 4            0         0    0

# %%
# save_act: 저축 예금 계좌 보유 여부
# current_act: 당좌 예금 계좌(또는 자유 입출금 계좌) 보유 여부
# mortage=?, pep= 보헌가입여부

# %%
namki[0:2]
# Out:
#         id  age  sex  region   income  married  children  car  save_act  \
# 0  ID12101   48    0       0  17546.0        0         1    0         0
# 1  ID12102   40    1       3  30085.1        1         3    1         0
#
#    current_act  mortgage  pep
# 0            0         0    1
# 1            1         1    0

# %%
namki[0:1]
# Out:
#         id  age  sex  region   income  married  children  car  save_act  \
# 0  ID12101   48    0       0  17546.0        0         1    0         0
#
#    current_act  mortgage  pep
# 0            0         0    1

# %%
namki.shape
# Out:
# (600, 12)

# %%
namki['age'].mean()
# Out:
# np.float64(42.395)

# %%
namki['income'].mean()
# Out:
# np.float64(27524.031216666666)

# %%
m = namki['age'].mean()
s = namki['age'].std()

# %%
m
# Out:
# np.float64(42.395)

# %%
namki[namki['age'] > m]
# Out:
#           id  age  sex  region   income  married  children  car  save_act  \
# 0    ID12101   48    0       0  17546.0        0         1    0         0
# 2    ID12103   51    0       0  16575.4        1         0    1         1
# 4    ID12105   57    0       1  50576.3        1         0    0         1
# 5    ID12106   57    0       3  37869.6        1         2    0         1
# 7    ID12108   58    1       3  24946.6        1         0    1         1
# ..       ...  ...  ...     ...      ...      ...       ...  ...       ...
# 588  ID12689   58    1       1  49673.6        1         0    0         1
# 592  ID12693   48    1       3  20268.0        1         0    0         1
# 593  ID12694   65    1       2  51417.0        1         2    0         1
# 594  ID12695   59    0       1  30971.8        1         3    1         1
# 595  ID12696   61    0       0  47025.0        0         2    1         1
#
#      current_act  mortgage  pep
# 0              0         0    1
# ...

# %%
namki.groupby('sex')['income'].mean()
# Out:
# sex
# 0    27831.368233
# 1    27216.694200
# Name: income, dtype: float64

# %%
namki.groupby('sex')['income'].mean().sort_values()
# Out:
# sex
# 1    27216.694200
# 0    27831.368233
# Name: income, dtype: float64

# %%
namki.groupby(['region', 'sex'])['income'].mean().sort_values()
# Out:
# region  sex
# 0       1      26538.128188
# 3       0      26730.686087
#         1      26849.572469
# 0       0      27166.216031
# 2       0      28573.271667
#         1      28734.249375
# 1       1      28743.575918
#         0      31366.274468
# Name: income, dtype: float64

# %%
namki.groupby(['age','sex'])['income'].mean().sort_values()
# Out:
# age  sex
# 18   1      10476.966000
# 21   1      10570.060000
#      0      11161.895000
# 22   1      12160.287000
# 19   0      12694.173333
#                 ...
# 66   0      45775.114286
# 63   1      46080.170000
#      0      46124.600000
# 64   1      49731.487500
# 65   1      49856.375000
# Name: income, Length: 99, dtype: float64

# %%
grouped = namki.groupby('region')

# %%
grouped.get_group(1)
# Out:
#           id  age  sex  region    income  married  children  car  save_act  \
# 4    ID12105   57    0       1  50576.30        1         0    0         1
# 6    ID12107   22    1       1   8877.07        0         0    0         0
# 14   ID12115   36    1       1  19474.60        1         0    0         1
# 29   ID12130   61    1       1  24270.10        1         1    0         0
# 30   ID12131   61    0       1  22942.90        1         2    0         1
# ..       ...  ...  ...     ...       ...      ...       ...  ...       ...
# 562  ID12663   57    0       1  50897.60        1         0    0         1
# 570  ID12671   49    0       1  33665.50        0         3    1         0
# 583  ID12684   47    0       1  29093.10        0         2    1         1
# 588  ID12689   58    1       1  49673.60        1         0    0         1
# 594  ID12695   59    0       1  30971.80        1         3    1         1
#
#      current_act  mortgage  pep
# 4              0         0    0
# ...

# %%
grouped['income'].agg([np.sum, np.mean, np.std])
# Out:
# C:\Users\10414\AppData\Local\Temp\ipykernel_5404\2574230428.py:1: FutureWarning: The provided callable <function sum at 0x0000021B9881F420> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped['income'].agg([np.sum, np.mean, np.std])
# C:\Users\10414\AppData\Local\Temp\ipykernel_5404\2574230428.py:1: FutureWarning: The provided callable <function mean at 0x0000021B98834860> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped['income'].agg([np.sum, np.mean, np.std])
# ...

# %%
def over_income_30000(group):
    return group['income'].mean() > 30000

# %%
grouped.filter(over_income_30000)
# Out:
#           id  age  sex  region    income  married  children  car  save_act  \
# 4    ID12105   57    0       1  50576.30        1         0    0         1
# 6    ID12107   22    1       1   8877.07        0         0    0         0
# 14   ID12115   36    1       1  19474.60        1         0    0         1
# 29   ID12130   61    1       1  24270.10        1         1    0         0
# 30   ID12131   61    0       1  22942.90        1         2    0         1
# ..       ...  ...  ...     ...       ...      ...       ...  ...       ...
# 562  ID12663   57    0       1  50897.60        1         0    0         1
# 570  ID12671   49    0       1  33665.50        0         3    1         0
# 583  ID12684   47    0       1  29093.10        0         2    1         1
# 588  ID12689   58    1       1  49673.60        1         0    0         1
# 594  ID12695   59    0       1  30971.80        1         3    1         1
#
#      current_act  mortgage  pep
# 4              0         0    0
# ...

# %%
pd.pivot_table(namki, columns = 'region')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     893 for i, group in enumerate(splitter):
# --> 894     res = func(group)
# ...

# %%
pd.pivot_table(namki, columns = 'region', index = 'id', values = 'income', aggfunc = np.mean)
# Out:
# C:\Users\10414\AppData\Local\Temp\ipykernel_5404\832956641.py:1: FutureWarning: The provided callable <function mean at 0x0000021B98834860> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(namki, columns = 'region', index = 'id', values = 'income', aggfunc = np.mean)
# region          0        1   2        3
# id
# ID12101  17546.00      NaN NaN      NaN
# ID12102       NaN      NaN NaN  30085.1
# ID12103  16575.40      NaN NaN      NaN
# ID12104       NaN      NaN NaN  20375.4
# ID12105       NaN  50576.3 NaN      NaN
# ...           ...      ...  ..      ...
# ID12696  47025.00      NaN NaN      NaN
# ID12697   9672.25      NaN NaN      NaN
# ID12698       NaN      NaN NaN  15976.3
# ID12699  14711.80      NaN NaN      NaN
# ID12700       NaN      NaN NaN  26671.6
#
# [600 rows x 4 columns]

# %%
pd.pivot_table(namki, columns = 'region', index = 'id', values = 'income', aggfunc = np.mean).fillna(0)
# Out:
# C:\Users\10414\AppData\Local\Temp\ipykernel_5404\2503944985.py:1: FutureWarning: The provided callable <function mean at 0x0000021B98834860> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(namki, columns = 'region', index = 'id', values = 'income', aggfunc = np.mean).fillna(0)
# region          0        1    2        3
# id
# ID12101  17546.00      0.0  0.0      0.0
# ID12102      0.00      0.0  0.0  30085.1
# ID12103  16575.40      0.0  0.0      0.0
# ID12104      0.00      0.0  0.0  20375.4
# ID12105      0.00  50576.3  0.0      0.0
# ...           ...      ...  ...      ...
# ID12696  47025.00      0.0  0.0      0.0
# ID12697   9672.25      0.0  0.0      0.0
# ID12698      0.00      0.0  0.0  15976.3
# ID12699  14711.80      0.0  0.0      0.0
# ID12700      0.00      0.0  0.0  26671.6
#
# [600 rows x 4 columns]
